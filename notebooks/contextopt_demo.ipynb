# %% [markdown]
# # ContextOpt Demo
#
# This notebook runs the ContextOpt experiment code from GitHub.

# %%
# !git clone https://github.com/rissingh23/Context-Opt.git
# %cd Context-Opt
# !pip install -r requirements.txt
